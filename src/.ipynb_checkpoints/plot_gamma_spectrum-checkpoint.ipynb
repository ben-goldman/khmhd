# %% [markdown]
# ## $Re = 900, Pm = 1, N = 128^3$, white-noise initial velocity perturbation, $\sigma_U = 1\times10^{-8}$, uniform magnetic field $\vec{B}_0 = 1\times10^{-8}\times(\hat\imath + \hat\jmath + \hat{k})$

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colormaps, cm, colors, ticker
import h5py
from findiff import FinDiff
from numpy import log10 as log

# %%
f = h5py.File("out_M8_Re900.0.h5")
B_kt = f["Bk"][2:]
U_kt = f["Uk"][2:]
B_t = f["B_mean"][2:, 0]
U_t = f["U_mean"][2:, 0]
B_kt[B_kt==0.0] = np.nan
U_kt[U_kt==0.0] = np.nan

# %%
ts = f["sim_time"][2:]/(2*np.pi)
k = np.arange(1, len(B_kt[0])+1)
kk, tt = np.meshgrid(k, ts)

# %% [markdown]
# Compute $\gamma_B = \partial_t(\ln(B(k, t)))$

# %%
d_dt = FinDiff(0, ts[1] - ts[0])
gU_kt = d_dt(np.log(U_kt))
gB_kt = d_dt(np.log(B_kt))
gU_kt[(gU_kt > 50)] = np.nan
gB_kt[(gB_kt > 50)] = np.nan
gB_t = d_dt(np.log(B_t))
gU_t = d_dt(np.log(U_t))

# %%
fig, axs = plt.subplots(2,2, sharex=True, sharey=True, figsize=(15, 8))
datas = np.array([[U_kt, B_kt], [gU_kt, gB_kt]])
titles = np.array([["$U^2(k, t)$", "$B^2(k, t)$"], ["$\gamma_U(k, t)$", "$\gamma_B(k, t)$"]])

for i in (0, 1):
    if not i:
        cmap = colormaps["viridis"]
        normalizer = colors.LogNorm(1e-24, 1e-1)
        im = cm.ScalarMappable(norm=normalizer, cmap=cmap)
        tk=ticker.LogLocator(numticks=30)
    else:
        cmap = colormaps["RdBu"]
        normalizer = colors.Normalize(-50, 50)
        im = cm.ScalarMappable(norm=normalizer, cmap=cmap)
        tk = ticker.LinearLocator()
    for j in (0, 1):
        data = datas[i, j]
        ax = axs[i, j]
        ax.contourf(tt, kk, data, cmap=cmap, norm=normalizer, locator=tk)
        ax.set_yscale("log", base=2)
        ax.set_title(titles[i, j])
        if i:
            ax.set_xlabel("$t$")
        if not j:
            ax.set_ylabel("$k$")
    fig.colorbar(im, ax=axs[i].ravel().tolist())
fig.suptitle("Kinetic and magnetic energy spectra for KH simulation")
# plt.savefig("gamma_spectrum.pdf")
# Out:
# Text(0.5, 0.98, 'Kinetic and magnetic energy spectra for KH simulation')

# %%
plt.plot(ts, gB_t, label="B")
plt.plot(ts[1:], gU_t[1:], label="U")
plt.legend()
plt.xlabel("$t$")
plt.ylabel(r"$\gamma(t)$")
plt.suptitle("Logarithmic growth rate")
# Out:
# Text(0.5, 0.98, 'Logarithmic growth rate')

# %%
B_kmaxt = np.nanmax(gB_kt, axis=1)
K_tmaxB = np.nanargmax(gB_kt, axis=1) + 1
U_kmaxt = np.nanmax(gU_kt, axis=1)
K_tmaxU = np.nanargmax(gU_kt, axis=1) + 1

# %%
plt.plot(B_kmaxt, label="B")
plt.plot(U_kmaxt, label="U")
plt.xlabel("$t$")
plt.ylabel(r"$\gamma(t)$")
plt.suptitle("Logarithmic growth rate for fastest-growing wavenumber")
plt.legend()

# %%
plt.plot(ts[K_tmaxB < 40], K_tmaxB[K_tmaxB < 40], label="B")
plt.plot(ts[K_tmaxU < 40], K_tmaxU[K_tmaxU < 40], label="U")
plt.xlabel("$t$")
plt.ylabel(r"$k$")
plt.legend()
plt.suptitle("Fastest-growing wavenumber")
plt.yscale("log", base=2)
