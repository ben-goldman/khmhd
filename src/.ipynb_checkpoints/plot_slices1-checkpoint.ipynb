# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib import colors
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
f = h5py.File("img_M8_Re900.0_w.h5")

# %%
f["UB0/3D/500"]
# Out:
# <HDF5 dataset "500": shape (256, 256, 256), type "<f8">

# %%
ts = np.array([500, 1000, 1500, 2000, 3000])
extent = (0, 2*np.pi, 0, 2*np.pi)
print(ts)
# Out:
# [ 500 1000 1500 2000 3000]

# %%
tmin = 500
tmax = 5000
u2min = 0
b2min = 1e-18
u2max = 2
b2max = 1e-10
fig, axs = plt.subplots(nrows=2, ncols=len(ts), figsize=(13, 5), sharey=True, sharex=True)
for (i, t) in enumerate(ts):
    print(t)
    u2 = f[f"UB0/3D/{t}"][:]**2 + f[f"UB1/3D/{t}"][:]**2 + f[f"UB2/3D/{t}"][:]**2
    b2 = f[f"UB3/3D/{t}"][:]**2 + f[f"UB4/3D/{t}"][:]**2 + f[f"UB5/3D/{t}"][:]**2
    c1 = axs[0, i].imshow(u2[128, :, :], extent=extent, norm=colors.Normalize(vmin=u2min, vmax=u2max))
    c2 = axs[1, i].imshow(b2[128, :, :], extent=extent, norm=colors.LogNorm(vmin=b2min, vmax=b2max))

d1 = make_axes_locatable(axs[0, -1])
d2 = make_axes_locatable(axs[1, -1])
cax1 = d1.append_axes("right", "5%", pad="3%")
cax2 = d2.append_axes("right", "5%", pad="3%")
fig.colorbar(c1, cax=cax1)
fig.colorbar(c2, cax=cax2)
fig.tight_layout()
plt.savefig("images.pdf")
plt.show()
# Out:
# 500
# 1000
# 1500
# 2000
# 3000

# %%
Nx, Ny, Nz = 256, 256, 256
X, Y, Z = np.meshgrid(np.arange(Nx), np.arange(Ny), -np.arange(Nz))
t=500
data = np.log(f[f"UB3/3D/{t}"][:]**2 + f[f"UB4/3D/{t}"][:]**2 + f[f"UB5/3D/{t}"][:]**2)
kw = {
    'vmin': data.min(),
    'vmax': data.max(),
    'levels': np.linspace(data.min(), data.max(), 30),
}
fig = plt.figure(figsize=(16, 15))
ax = fig.add_subplot(111, projection='3d')

# Plot contour surfaces
_ = ax.contourf(
    X[:, :, 0], Y[:, :, 0], data[:, :, 0],
    zdir='z', offset=0, **kw
)
_ = ax.contourf(
    X[0, :, :], data[0, :, :], Z[0, :, :],
    zdir='y', offset=0, **kw
)
C = ax.contourf(
    data[:, -1, :], Y[:, -1, :], Z[:, -1, :],
    zdir='x', offset=X.max(), **kw
)

# Set zoom and angle view
ax.view_init(40, -30, 0)
ax.set_box_aspect(None, zoom=0.9)
